# %%
from os.path import join
import pandas as pd
import requests # Webcrawling
from pathlib import Path

from dotenv import dotenv_values
ENV = dotenv_values(".env")

# %%
ENV
# Out:
# OrderedDict([('EDAMAM_ID', 'd93bfa58'),
#              ('EDAMAM_KEY', 'a7912faa21fcc203018f79d5cecae102')])

# %%
protocole = "https://"
domain = "api.edamam.com/"
endpoint = "api/recipes/v2"

# %%
URL = join(protocole,domain,endpoint)
URL = 'https://api.edamam.com/api/recipes/v2'

SAVE_DIR = './Exports/'

# %%
params = {
    "type": "public",
    "q": "Soda",
    "app_id": ENV["EDAMAM_ID"],
    "app_key": ENV["EDAMAM_KEY"]
}

response = requests.get(URL, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'from': 1,
#  'to': 20,
#  'count': 10000,
#  '_links': {'next': {'href': 'https://api.edamam.com/api/recipes/v2?q=SODA&app_key=a7912faa21fcc203018f79d5cecae102&_cont=CHcVQBtNNQphDmgVQntAEX4BYUtxAwQDSmZFB2oSalVwBQYBUXlSVjEUZ1chAAoHQGZCAWUUNV17UlIGFTZBVWUWNQR6AwIVLnlSVSBMPkd5BgNK&type=public&app_id=d93bfa58',
#    'title': 'Next page'}},
#  'hits': [{'recipe': {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_ae9836cc51974795ad992e4caffe1dd5',
#     'label': 'Soda farls',
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['from', 'to', 'count', '_links', 'hits'])

# %%
for key in response.json().keys():
    print(key, ': ',response.json()[key])
# Out:
# from :  1
# to :  20
# count :  10000
# _links :  {'next': {'href': 'https://api.edamam.com/api/recipes/v2?q=SODA&app_key=a7912faa21fcc203018f79d5cecae102&_cont=CHcVQBtNNQphDmgVQntAEX4BYUtxAwQDSmZFB2oSalVwBQYBUXlSVjEUZ1chAAoHQGZCAWUUNV17UlIGFTZBVWUWNQR6AwIVLnlSVSBMPkd5BgNK&type=public&app_id=d93bfa58', 'title': 'Next page'}}
# ...

# %%
response.json()['hits']
# Out:
# [{'recipe': {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_ae9836cc51974795ad992e4caffe1dd5',
#    'label': 'Soda farls',
# ...

# %%
response.json()['hits']
# Out:
# [{'recipe': {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_ae9836cc51974795ad992e4caffe1dd5',
#    'label': 'Soda farls',
# ...

# %%
# Extraire la liste de dictionnaires
hits = response.json()['hits']

# Obtenir les clés du premier dictionnaire
first_keys = set(hits[0].keys())

# Vérifier que tous les dictionnaires ont les mêmes clés
all_same_keys = all(set(hit.keys()) == first_keys for hit in hits)

print("Tous les dictionnaires ont les mêmes clés:", all_same_keys)
# Out:
# Tous les dictionnaires ont les mêmes clés: True

# %%
hits[0].keys()
# Out:
# dict_keys(['recipe', '_links'])

# %%
for key in hits[0].keys():
    print(key, ': ', hits[0][key])
# Out:
# recipe :  {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_ae9836cc51974795ad992e4caffe1dd5', 'label': 'Soda farls', 'image': 'https://edamam-product-images.s3.amazonaws.com/web-img/2aa/2aaebc79372e2b48c4da5de0d8c66cbe.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEDgaCXVzLWVhc3QtMSJGMEQCIHHIPWvMLieJ6nvgeAFQF6XwJSeu8fmnX2r63HXEvQPRAiAndelN0IOl7W%2FuKsj8n5lUqTeNP6CYs7HmIYWz49e18CrCBQih%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDE4NzAxNzE1MDk4NiIM47A4qKVmNw%2FjrLwHKpYFTp8pvbqlZl67BOR1ky7NGxNr2nuYA%2BC9IwwDAa8UUGnqsbDIRuQ4UNwc4qGXDH%2FfSdxQI62zd%2FgLFdAHSVLpoGjVHMm5V8BFBifazFgMu0uAnYHhcIuV1ab7HaHL%2BCDrFdL4LSzf%2F7ePclNGrM1z%2BAU6a6PVzKl8Cah4MS6g6GxfgSXAEW3T%2FcB58FbbEeUViVcNwRSruXKb%2BK3g%2BhqnGQpVi3X%2BafoAEvsK7IvIyPNJbSwI0tBGqIETxSazEqmYWhy5iYzI%2BA%2FIkeq6DFkGq1VLh3CM%2Fh0c1d%2Bls%2FggkNui53y04mgxnKIgE4KSu5z%2FyaOUKLuginARxVCJjOjHyL3KDLellTIu46f%2F8ZlXiXSwIcK2H9rCJLcT7MyJHjTw5vVPquMUlJ1kgpoXGUvvV99FckmcEoNY00qv09TRhuRtr7iaboPLX1jUdRgfWc%2BQO4HMvaNkeBxP2V8PpDa0rdTbqKIVTDSegnZWyI%2BTC
# ...

# %%
hits[0]['recipe']
# Out:
# {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_ae9836cc51974795ad992e4caffe1dd5',
#  'label': 'Soda farls',
# ...

# %%
for key in (hits[0]['recipe'].keys()):
    print(key)
# Out:
# uri
# label
# image
# images
# source
# url
# shareAs
# yield
# dietLabels
# healthLabels
# cautions
# ingredientLines
# ingredients
# calories
# totalCO2Emissions
# co2EmissionsClass
# totalWeight
# totalTime
# cuisineType
# mealType
# dishType
# totalNutrients
# totalDaily
# digest
# tags

# %%
hits[0]['recipe']['dishType']
# Out:
# ['biscuits and cookies']

# %%
cles_travail = [
    'uri', 
    'label', 
    'dishType', 
    'ingredients', 
    'image'
    ]

# %%
from PIL import Image
import requests
from io import BytesIO

# URL de l'image
image_url = hits[0]['recipe']['image']

# Télécharger l'image
response = requests.get(image_url)
img = Image.open(BytesIO(response.content))

# Afficher l'image
img.show()

# %%
def extract_edamam_recipies(ingredient:str, nb):
    number_of_recipies = int(nb)

    params = {
        "type":"public",
        "q":f"{ingredient}",
        "app_id":ENV["EDAMAM_ID"],
        "app_key":ENV["EDAMAM_KEY"]
    }

    response = requests.get(URL,params=params) # Regarder si on peut limiter la requête
    
    Path(SAVE_DIR).mkdir(parents=True,exist_ok=True) # A réutiliser
    save_path = join(SAVE_DIR,ingredient.replace(" ","_")+".csv")
    
    df_recipe = pd.DataFrame([x['recipe'] for x in response.json()['hits']]).head(  )
    df_recipe = df_recipe[KEEP_COLUMNS]
    df_recipe.to_csv(save_path,index=False)
    print(f"    ---")
    print(f"    ## {nb} {ingredient} recipes saved in {save_path} ##")
    print(f"    ---")

# %%
params = {
        "type":"public",
        "q":'milk',
        "app_id":ENV["EDAMAM_ID"],
        "app_key":ENV["EDAMAM_KEY"]
    }

response = requests.get(URL,params=params)

# %%
response
# Out:
# <Response [200]>

# %%
response.json().keys()
# Out:
# dict_keys(['from', 'to', 'count', '_links', 'hits'])

# %%
response.json()['hits'][0].keys()
# Out:
# dict_keys(['recipe', '_links'])

# %%
response.json()['hits'][0]['recipe'].keys()
# Out:
# dict_keys(['uri', 'label', 'image', 'images', 'source', 'url', 'shareAs', 'yield', 'dietLabels', 'healthLabels', 'cautions', 'ingredientLines', 'ingredients', 'calories', 'totalCO2Emissions', 'co2EmissionsClass', 'totalWeight', 'totalTime', 'cuisineType', 'mealType', 'dishType', 'totalNutrients', 'totalDaily', 'digest', 'tags'])

# %%
extract_edamam_recipies('milk', 5)
# Out:
#     ---
#     ## 5 milk recipes saved in ./Exports/milk.csv ##
#     ---

# %%
milk = pd.read_csv('./Exports/milk.csv')

# %%
milk
# Out:
#                                                  uri            label  \
# 0  http://www.edamam.com/ontologies/edamam.owl#re...     Milk Liqueur
# 1  http://www.edamam.com/ontologies/edamam.owl#re...       Milk Punch
# 2  http://www.edamam.com/ontologies/edamam.owl#re...       Pinky Milk
# 3  http://www.edamam.com/ontologies/edamam.owl#re...  Strawberry Milk
# 4  http://www.edamam.com/ontologies/edamam.owl#re...       Milk Toast
#
#                                                image  \
# 0  https://edamam-product-images.s3.amazonaws.com...
# 1  https://edamam-product-images.s3.amazonaws.com...
# 2  https://edamam-product-images.s3.amazonaws.com...
# 3  https://edamam-product-images.s3.amazonaws.com...
# 4  https://edamam-product-images.s3.amazonaws.com...
#
#                                         healthLabels  \
# 0  ['Low Potassium', 'Kidney-Friendly', 'Vegetari...
# 1  ['Vegetarian', 'Pescatarian', 'Gluten-Free', '...
# 2  ['Vegetarian', 'Pescatarian', 'Gluten-Free', '...
# ...
